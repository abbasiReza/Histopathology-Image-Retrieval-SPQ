# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd 
# %cd drive/MyDrive/models/SPQ/
# Out:
# /content
# /content/drive/MyDrive/models/SPQ

# %%
# !pip install kornia
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.7/dist-packages (0.6.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from kornia) (21.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from kornia) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.8.1->kornia) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->kornia) (3.0.7)

# %%
# !nvidia-smi
# Out:
# Sun Mar  6 07:02:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Out:
# Collecting torchinfo==0.0.1
#   Downloading torchinfo-0.0.1-py3-none-any.whl (1.6 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-0.0.1

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
from torchsummary import summary

# %%
from utils import *
from tqdm import tqdm
from dataset import SingleData
import math

def get_data_list(data_path, ratio=0.0):
    img_list = []
    for root, dirs, files in os.walk(data_path):
        if files == []:
            class_name = dirs
        elif dirs == []:
            for f in files:
                img_path = os.path.join(root, f)
                img_list.append(img_path)

    np.random.seed(1)
    train_img_list = np.random.choice(img_list, size=int(len(img_list)*(1-ratio)), replace=False)
    #print(img_list, train_img_list)
    eval_img_list = list(set(img_list) - set(train_img_list))
    ########add
    half=math.floor(len(eval_img_list)/2)
    print(half)
    eval_=eval_img_list[:half]
    test_=eval_img_list[half:]
    #######
    #return class_name, train_img_list, eval_img_list 
    return class_name, train_img_list

def pqDist_one(C, N_books, g_x, q_x,query_pname,gallery_pname):
    l1, l2 = C.shape
    L_word = int(l2/N_books)
    D_C = T.zeros((l1, N_books), dtype=T.float32)

    q_x_split = T.split(q_x, L_word, 0)
    g_x_split = np.split(g_x.cpu().data.numpy(), N_books, 1)
    C_split = T.split(C, L_word, 1)
    D_C_split = T.split(D_C, 1, 1)

    for j in range(N_books):
        for k in range(l1):
            # D_C_split[j][k] =T.norm(q_x_split[j]-C_split[j][k], 2)
            D_C_split[j][k] = T.norm(q_x_split[j]-C_split[j][k], 2).detach() #for PyTorch version over 1.9
        if j == 0:
            dist = D_C_split[j][g_x_split[j]]
        else:
            dist = T.add(dist, D_C_split[j][g_x_split[j]])
    Dpq = T.squeeze(dist)
#     ##### TASK
#     for i in range(len(gallery_pname)):
#         if query_pname==gallery_pname[i]:
#             Dpq[i]=float('inf')
#     #####
    return Dpq

def Indexing(C, N_books, X):
    l1, l2 = C.shape
    L_word = int(l2/N_books)
    x = T.split(X, L_word, 1)
    y = T.split(C, L_word, 1)
    for i in range(N_books):
        diff = squared_distances(x[i], y[i])
        arg = T.argmin(diff, dim=1)
        min_idx = T.reshape(arg, [-1, 1])
        if i == 0:
            quant_idx = min_idx
        else:
            quant_idx = T.cat((quant_idx, min_idx), dim=1)
    return quant_idx

def Evaluate_mAP(C, N_books, gallery_codes, query_codes, gallery_labels, query_labels, device,gallery_pname,query_pname, TOP_K=None):
    num_query = query_labels.shape[0]
    mean_AP = 0.0

    with tqdm(total=num_query, desc="Evaluate mAP", bar_format='{desc:<15}{percentage:3.0f}%|{bar:10}{r_bar}') as pbar:
        for i in range(num_query):
            # Retrieve images from database
            retrieval = (query_labels[i, :] @ gallery_labels.t() > 0).float()

            # Arrange position according to hamming distance
            retrieval = retrieval[T.argsort(pqDist_one(C, N_books, gallery_codes, query_codes[i],query_pname[i],gallery_pname))][:TOP_K]

            # Retrieval count
            retrieval_cnt = retrieval.sum().int().item()

            # Can not retrieve images
            if retrieval_cnt == 0:
                continue

            # Generate score for every position
            score = T.linspace(1, retrieval_cnt, retrieval_cnt).to(device)

            # Acquire index
            index = (T.nonzero(retrieval == 1, as_tuple=False).squeeze() + 1.0).float().to(device)

            mean_AP += (score / index).mean()
            pbar.update(1)

        mean_AP = mean_AP / num_query
    return mean_AP

def DoRetrieval(device, args, net, C):
    print("Do Retrieval!")


    class_name, train_img_list = get_data_list('content/drive/MyDrive/dataSets/CRC/train')
    train_data_set=SingleData(class_name, train_img_list, transform=transforms.ToTensor())
    Gallery_loader = T.utils.data.DataLoader(train_data_set, batch_size=args.batch_size, shuffle=False, num_workers=args.num_workers)

    # trainset = torchvision.datasets.CIFAR10(root=args.data_dir, train=True, download=args.if_download, transform=transforms.ToTensor())
    # Gallery_loader = T.utils.data.DataLoader(trainset, batch_size=args.batch_size, shuffle=False, num_workers=args.num_workers)
    class_test_name, test_img_list = get_data_list('content/drive/MyDrive/dataSets/CRC/same test')
    test_data_set = SingleData(class_test_name, test_img_list, transform=transforms.ToTensor())    
    
    # testset = torchvision.datasets.CIFAR10(root=args.data_dir, train=False, download=args.if_download, transform=transforms.ToTensor())
    Query_loader = T.utils.data.DataLoader(test_data_set, batch_size=args.batch_size, shuffle=False, num_workers=args.num_workers)

    net.eval()
    with T.no_grad():
        with tqdm(total=len(Gallery_loader), desc="Build Gallery", bar_format='{desc:<15}{percentage:3.0f}%|{bar:10}{r_bar}') as pbar:
            for i, data in enumerate(Gallery_loader, 0):
                gallery_x_batch, gallery_y_batch = data[0].to(device), data[1].to(device)
                gallery_y_batch=gallery_y_batch.long()
                outputs = net(gallery_x_batch)
                gallery_c_batch = Indexing(C, args.N_books, outputs[0])
                gallery_y_batch = T.eye(args.num_cls)[gallery_y_batch]
                temp=[]
                for s in data[2]:
                    index1=s.rfind('/')
                    temp.append(s[index1+4:index1+7])
                    print(s[index1+4:index1+7])
                    
                if i == 0:
                    gallery_c = gallery_c_batch
                    gallery_y = gallery_y_batch
                    gallery_pname=temp
                else:
                    gallery_c = T.cat([gallery_c, gallery_c_batch], 0)
                    gallery_y = T.cat([gallery_y, gallery_y_batch], 0)
                    gallery_pname=gallery_pname + temp
                pbar.update(1)

        with tqdm(total=len(Query_loader), desc="Compute Query", bar_format='{desc:<15}{percentage:3.0f}%|{bar:10}{r_bar}') as pbar:
            for i, data in enumerate(Query_loader, 0):
                query_x_batch, query_y_batch = data[0].to(device), data[1].to(device)
                query_y_batch=query_y_batch.long()
                outputs = net(query_x_batch)
                query_y_batch = T.eye(args.num_cls)[query_y_batch]
                
                temp=[]
                for s in data[2]:
                    index1=s.rfind('/')
                    temp.append(s[index1+4:index1+7])
                    

                if i == 0:
                    query_c = outputs[0]
                    query_y = query_y_batch
                    query_pname=temp
                else:
                    query_c = T.cat([query_c, outputs[0]], 0)
                    query_y = T.cat([query_y, query_y_batch], 0)
                    query_pname=query_pname+temp
                pbar.update(1)

    mAP = Evaluate_mAP(C, args.N_books, gallery_c.type(T.int), query_c, gallery_y, query_y, device,gallery_pname,query_pname, args.Top_N)
    return mAP

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR
from utils import *
from Retrieval import *
from dataset import SingleData
import math


def get_data_list(data_path, ratio=0.0):
    img_list = []
    for root, dirs, files in os.walk(data_path):
        if files == []:
            class_name = dirs
        elif dirs == []:
            for f in files:
                img_path = os.path.join(root, f)
                img_list.append(img_path)

    np.random.seed(1)
    train_img_list = np.random.choice(img_list, size=int(len(img_list)*(1-ratio)), replace=False)
    #print(img_list, train_img_list)
    eval_img_list = list(set(img_list) - set(train_img_list))
    ########add
    half=math.floor(len(eval_img_list)/2)
    print(half)
    eval_=eval_img_list[:half]
    test_=eval_img_list[half:]
    #######
    #return class_name, train_img_list, eval_img_list 
    return class_name, train_img_list


def get_args_parser():
    parser = argparse.ArgumentParser('SPQ', add_help=False)

    parser.add_argument('--gpu_id', default="0", type=str, help="""Define GPU id.""")
    parser.add_argument('--if_download', default=False, type=bool, help="""Whether to download the dataset or not.""")
    parser.add_argument('--data_dir', default="./data", type=str, help="""Path of the dataset to be installed.""")
    # parser.add_argument('--batch_size', default=256, type=int, help="""Training mini-batch size.""")
    parser.add_argument('--batch_size', default=32, type=int, help="""Training mini-batch size.""")
    parser.add_argument('--num_workers', default=4, type=int, help="""Number of data loading workers per GPU.""")
    parser.add_argument('--input_size', default=216, type=int, help="""Input image size, default is set to CIFAR10.""")

    parser.add_argument('--N_books', default=8, type=int, help="""The number of the codebooks.""")
    parser.add_argument('--N_words', default=16, type=int, help="""The number of the codewords. It should be a power of two.""")
    parser.add_argument('--L_word', default=16, type=int, help="""Dimensionality of the codeword.""")
    parser.add_argument('--soft_quantization_scale', default=5.0, type=float, help="""Soft-quantization scaling parameter.""")
    parser.add_argument('--contrastive_temperature', default=0.5, type=float, help="""Contrastive learning Temperature scaling parameter.""")
    
    parser.add_argument('--num_cls', default="3", type=int, help="""The number of classes in the dataset for evaluation, default is set to CIFAR10""")
    parser.add_argument('--eval_epoch', default=50, type=int, help="""Compute mAP for Every N-th epoch.""")
    # parser.add_argument('--eval_epoch', default=100, type=int, help="""Compute mAP for Every N-th epoch.""")
    parser.add_argument('--output_dir', default=".", type=str, help="""Path to save logs and checkpoints.""")
    parser.add_argument('--Top_N', default=100, type=int, help="""Top N number of images to be retrieved for evaluation.""")
    
    return parser
class CQCLoss(T.nn.Module):

    def __init__(self, device, batch_size, tau_cqc):
        super(CQCLoss, self).__init__()
        self.batch_size = batch_size
        self.tau_cqc = tau_cqc
        self.device = device
        self.COSSIM = T.nn.CosineSimilarity(dim=-1)
        self.CE = T.nn.CrossEntropyLoss(reduction="sum")
        self.get_corr_mask = self._get_correlated_mask().type(T.bool)

    def _get_correlated_mask(self):
        diag = np.eye(2 * self.batch_size)
        l1 = np.eye((2 * self.batch_size), 2 * self.batch_size, k=-self.batch_size)
        l2 = np.eye((2 * self.batch_size), 2 * self.batch_size, k=self.batch_size)
        mask = T.from_numpy((diag + l1 + l2))
        mask = (1 - mask).type(T.bool)
        return mask.to(self.device)

    def forward(self, Xa, Xb, Za, Zb):

        XaZb = T.cat([Xa, Zb], dim=0)
        XbZa = T.cat([Xb, Za], dim=0)

        Cossim_ab = self.COSSIM(XaZb.unsqueeze(1), XaZb.unsqueeze(0))
        Rab = T.diag(Cossim_ab, self.batch_size)
        Lab = T.diag(Cossim_ab, -self.batch_size)
        Pos_ab = T.cat([Rab, Lab]).view(2 * self.batch_size, 1)
        Neg_ab = Cossim_ab[self.get_corr_mask].view(2 * self.batch_size, -1)

        Cossim_ba = self.COSSIM(XbZa.unsqueeze(1), XbZa.unsqueeze(0))
        Rba = T.diag(Cossim_ba, self.batch_size)
        Lba = T.diag(Cossim_ba, -self.batch_size)    
        Pos_ba = T.cat([Rba, Lba]).view(2 * self.batch_size, 1)
        Neg_ba = Cossim_ba[self.get_corr_mask].view(2 * self.batch_size, -1)


        logits_ab = T.cat((Pos_ab, Neg_ab), dim=1)
        logits_ab /= self.tau_cqc

        logits_ba = T.cat((Pos_ba, Neg_ba), dim=1)
        logits_ba /= self.tau_cqc

        labels = T.zeros(2 * self.batch_size).to(self.device).long()
        
        loss = self.CE(logits_ab, labels) + self.CE(logits_ba, labels)
        return loss / (2 * self.batch_size)

def train_SPQ(args):
    os.environ["CUDA_VISIBLE_DEVICES"] = args.gpu_id
    device = T.device('cuda')
    # device = xm.xla_device()

    sz = args.input_size
    data_dir = args.data_dir
    batch_size = args.batch_size

    N_books = args.N_books
    N_words = args.N_words
    L_word = args.L_word
    tau_q = args.soft_quantization_scale
    tau_cqc = args.contrastive_temperature

    N_bits = int(N_books * np.sqrt(N_words))
    print('\033[91m' + '%d'%N_bits +  '-bit to retrieval' + '\033[0m')

    #Define the data augmentation following the setup of SimCLR
    Augmentation = nn.Sequential(
        Kg.RandomResizedCrop(size=(sz, sz)),
        Kg.RandomHorizontalFlip(p=0.5),
        Kg.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1, p=0.8),
        Kg.RandomGrayscale(p=0.2),
        Kg.RandomGaussianBlur((int(0.1 * sz), int(0.1 * sz)), (0.1, 2.0), p=0.5))

    transform = transforms.ToTensor()
    
    class_name, train_img_list = get_data_list('/content/drive/MyDrive/dataSets/CRC/train/')
    train_data_set=SingleData(class_name, train_img_list, transform)
    
    # trainset = torchvision.datasets.CIFAR10(root=data_dir, train=True, download=args.if_download, transform=transform)
    trainloader = T.utils.data.DataLoader(train_data_set, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=args.num_workers)
    # trainloader = T.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=args.num_workers)
    # testset = torchvision.datasets.CIFAR10(root=args.data_dir, train=False, download=args.if_download, transform=transforms.ToTensor())
    class Quantization_Head(nn.Module):
        def __init__(self, N_words, N_books, L_word, tau_q):
            super(Quantization_Head, self).__init__()
            self.fc = nn.Linear(512, N_books * L_word)
            nn.init.xavier_uniform_(self.fc.weight)

            # Codebooks
            self.C = T.nn.Parameter(Variable((T.randn(N_words, N_books * L_word)).type(T.float32), requires_grad=True))
            nn.init.xavier_uniform_(self.C)

            self.N_books = N_books
            self.L_word = L_word
            self.tau_q = tau_q

        def forward(self, input):
            X = self.fc(input)
            Z = Soft_Quantization(X, self.C, self.N_books, self.tau_q)
            return X, Z
        
    Q = Quantization_Head(N_words, N_books, L_word, tau_q)
    net = nn.Sequential(ResNet_Baseline(BasicBlock, [2, 2, 2, 2]), Q)
    net.load_state_dict(T.load('/content/drive/MyDrive/models/SPQ/349_32_0.1871_checkpoint.pth'))
    # net.cuda(device)
    # summary(net,(3, 224, 224))
    # print(net._modules)
    return net
if __name__ == '__main__':
    parser = argparse.ArgumentParser('SPQ', parents=[get_args_parser()])
    args = parser.parse_args("")
    my_model=train_SPQ(args)
    print(my_model)
# Out:
# 32-bit to retrieval
# 0
# ['s1', 's2', 's3']
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sequential(
#   (0): ResNet_Baseline(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (fc_out): Linear(in_features=512, out_features=512, bias=True)
#   )
#   (1): Quantization_Head(
#     (fc): Linear(in_features=512, out_features=128, bias=True)
#   )
# )

# %%
my_model
# Out:
# Sequential(
#   (0): ResNet_Baseline(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (shortcut): Sequential()
#       )
#     )
#     (fc_out): Linear(in_features=512, out_features=512, bias=True)
#   )
#   (1): Quantization_Head(
#     (fc): Linear(in_features=512, out_features=128, bias=True)
#   )
# )

# %%
# !pip install onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.11.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 4.2 MB/s
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx) (3.10.0.2)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from onnx) (1.21.5)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.2->onnx) (1.15.0)
# Installing collected packages: onnx
# Successfully installed onnx-1.11.0

# %%
# !pip install tensorflow-addons
# !git clone https://github.com/onnx/onnx-tensorflow.git && cd onnx-tensorflow && pip install -e .
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.3 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1
# Cloning into 'onnx-tensorflow'...
# remote: Enumerating objects: 6438, done.
# remote: Counting objects: 100% (387/387), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 6438 (delta 255), reused 267 (delta 175), pack-reused 6051
# Receiving objects: 100% (6438/6438), 2.01 MiB | 4.01 MiB/s, done.
# Resolving deltas: 100% (4980/4980), done.
# Checking out files: 100% (240/240), done.
# Obtaining file:///content/drive/MyDrive/models/SPQ/onnx-tensorflow
# Requirement already satisfied: onnx>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from onnx-tf==1.9.0) (1.11.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from onnx-tf==1.9.0) (3.13)
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (from onnx-tf==1.9.0) (0.16.1)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.9.0->onnx-tf==1.9.0) (3.17.3)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.9.0->onnx-tf==1.9.0) (1.21.5)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.9.0->onnx-tf==1.9.0) (3.10.0.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.2->onnx>=1.9.0->onnx-tf==1.9.0) (1.15.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons->onnx-tf==1.9.0) (2.7.1)
# Installing collected packages: onnx-tf
#   Running setup.py develop for onnx-tf
# Successfully installed onnx-tf-1.9.0

# %%
# !pip install pytorch2keras
# Out:
# Collecting pytorch2keras
#   Downloading pytorch2keras-0.2.4.tar.gz (21 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from pytorch2keras) (2.8.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from pytorch2keras) (2.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch2keras) (1.21.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch2keras) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from pytorch2keras) (0.11.1+cu111)
# Collecting onnx
#   Downloading onnx-1.11.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 40.0 MB/s
# Collecting onnx2keras
#   Downloading onnx2keras-0.0.24.tar.gz (20 kB)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx->pytorch2keras) (3.10.0.2)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx->pytorch2keras) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.2->onnx->pytorch2keras) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (1.44.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (0.2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (1.0.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (3.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (1.6.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (0.5.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (13.0.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 69.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (57.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (1.13.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->pytorch2keras) (0.24.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->pytorch2keras) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->pytorch2keras) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (4.11.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->pytorch2keras) (3.2.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->pytorch2keras) (7.1.2)
# Building wheels for collected packages: pytorch2keras, onnx2keras
#   Building wheel for pytorch2keras (setup.py) ... done
#   Created wheel for pytorch2keras: filename=pytorch2keras-0.2.4-py3-none-any.whl size=29677 sha256=5b5328d6bff9d0f1deb5f7bfa21e1cf6b758cd271999d6ec983cb78e333fc4c3
#   Stored in directory: /root/.cache/pip/wheels/72/4e/ee/8c004883e677ab4283783ffd9433ecf595327889dd367c79b1
#   Building wheel for onnx2keras (setup.py) ... done
#   Created wheel for onnx2keras: filename=onnx2keras-0.0.24-py3-none-any.whl size=24593 sha256=31199cdeefcb6bf60ec544ae9102c0dd3b5693e2768c4012c37957fbad91a7c7
#   Stored in directory: /root/.cache/pip/wheels/21/29/29/227fc9f8fed234b12169ae41f979cfadf1dcdbe1b370a5bbb5
# Successfully built pytorch2keras onnx2keras
# Installing collected packages: tf-estimator-nightly, onnx, onnx2keras, pytorch2keras
# Successfully installed onnx-1.11.0 onnx2keras-0.0.24 pytorch2keras-0.2.4 tf-estimator-nightly-2.8.0.dev2021122109

# %%
# !pip uninstall onnx
# Out:
# Found existing installation: onnx 1.11.0
# Uninstalling onnx-1.11.0:
#   Would remove:
#     /usr/local/bin/backend-test-tools
#     /usr/local/bin/check-model
#     /usr/local/bin/check-node
#     /usr/local/lib/python3.7/dist-packages/onnx-1.11.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/onnx/*
# Proceed (y/n)? y
#   Successfully uninstalled onnx-1.11.0

# %%
# !pip install onnx==1.8.1
# Out:
# Collecting onnx==1.8.1
#   Downloading onnx-1.8.1-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 29.8 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from onnx==1.8.1) (3.17.3)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from onnx==1.8.1) (1.21.5)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx==1.8.1) (3.10.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from onnx==1.8.1) (1.15.0)
# Installing collected packages: onnx
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.11.0
#     Uninstalling onnx-1.11.0:
#       Successfully uninstalled onnx-1.11.0
# Successfully installed onnx-1.8.1

# %%
from pytorch2keras.converter import pytorch_to_keras

# %%
import torch
input_np = np.random.uniform(0, 1, (1, 3, 224, 224))
input_var = Variable(torch.FloatTensor(input_np))

# %%
k_model = pytorch_to_keras(my_model, input_var)
# Out:
# /content/drive/MyDrive/models/SPQ/utils.py:93: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   out = F.avg_pool2d(out, int(out.size()[3]))
# /content/drive/MyDrive/models/SPQ/utils.py:15: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   L_word = int(C.size()[1]/N_books)
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# Trying to convert multi-output node
# Trying to convert multi-output node
# Failed to use keras.layers.Multiply. Fallback to TF lambda.
# Failed to use keras.layers.Multiply. Fallback to TF lambda.
# [0, 0, 0, 0, 0, 0, 0, 0]
# Failed to use keras.layers.Multiply. Fallback to TF lambda.
# Failed to use keras.layers.Multiply. Fallback to TF lambda.
# Failed to use keras.layers.Multiply. Fallback to TF lambda.
# Failed to use keras.layers.Multiply. Fallback to TF lambda.
# Failed to use keras.layers.Multiply. Fallback to TF lambda.
# Failed to use keras.layers.Multiply. Fallback to TF lambda.

# %%
k_model.summary ()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_0 (InputLayer)           [(None, 3, 224, 224  0           []
#                                 )]
#
#  297_pad (ZeroPadding2D)        (None, 3, 226, 226)  0           ['input_0[0][0]']
#
#  297 (Conv2D)                   (None, 64, 224, 224  1792        ['297_pad[0][0]']
#                                 )
#
#  128 (Activation)               (None, 64, 224, 224  0           ['297[0][0]']
#                                 )
#
#  300_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['128[0][0]']
#                                 )
#
#  300 (Conv2D)                   (None, 64, 224, 224  36928       ['300_pad[0][0]']
#                                 )
#
#  131 (Activation)               (None, 64, 224, 224  0           ['300[0][0]']
#                                 )
#
#  303_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['131[0][0]']
#                                 )
#
#  303 (Conv2D)                   (None, 64, 224, 224  36928       ['303_pad[0][0]']
#                                 )
#
#  134 (Add)                      (None, 64, 224, 224  0           ['303[0][0]',
#                                 )                                 '128[0][0]']
#
#  135 (Activation)               (None, 64, 224, 224  0           ['134[0][0]']
#                                 )
#
#  306_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['135[0][0]']
#                                 )
#
#  306 (Conv2D)                   (None, 64, 224, 224  36928       ['306_pad[0][0]']
#                                 )
#
#  138 (Activation)               (None, 64, 224, 224  0           ['306[0][0]']
#                                 )
#
#  309_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['138[0][0]']
#                                 )
#
#  309 (Conv2D)                   (None, 64, 224, 224  36928       ['309_pad[0][0]']
#                                 )
#
#  141 (Add)                      (None, 64, 224, 224  0           ['309[0][0]',
#                                 )                                 '135[0][0]']
#
#  142 (Activation)               (None, 64, 224, 224  0           ['141[0][0]']
#                                 )
#
#  312_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['142[0][0]']
#                                 )
#
#  312 (Conv2D)                   (None, 128, 112, 11  73856       ['312_pad[0][0]']
#                                 2)
#
#  145 (Activation)               (None, 128, 112, 11  0           ['312[0][0]']
#                                 2)
#
#  315_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['145[0][0]']
#                                 4)
#
#  315 (Conv2D)                   (None, 128, 112, 11  147584      ['315_pad[0][0]']
#                                 2)
#
#  318 (Conv2D)                   (None, 128, 112, 11  8320        ['142[0][0]']
#                                 2)
#
#  150 (Add)                      (None, 128, 112, 11  0           ['315[0][0]',
#                                 2)                                '318[0][0]']
#
#  151 (Activation)               (None, 128, 112, 11  0           ['150[0][0]']
#                                 2)
#
#  321_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['151[0][0]']
#                                 4)
#
#  321 (Conv2D)                   (None, 128, 112, 11  147584      ['321_pad[0][0]']
#                                 2)
#
#  154 (Activation)               (None, 128, 112, 11  0           ['321[0][0]']
#                                 2)
#
#  324_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['154[0][0]']
#                                 4)
#
#  324 (Conv2D)                   (None, 128, 112, 11  147584      ['324_pad[0][0]']
#                                 2)
#
#  157 (Add)                      (None, 128, 112, 11  0           ['324[0][0]',
#                                 2)                                '151[0][0]']
#
#  158 (Activation)               (None, 128, 112, 11  0           ['157[0][0]']
#                                 2)
#
#  327_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['158[0][0]']
#                                 4)
#
#  327 (Conv2D)                   (None, 256, 56, 56)  295168      ['327_pad[0][0]']
#
#  161 (Activation)               (None, 256, 56, 56)  0           ['327[0][0]']
#
#  330_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['161[0][0]']
#
#  330 (Conv2D)                   (None, 256, 56, 56)  590080      ['330_pad[0][0]']
#
#  333 (Conv2D)                   (None, 256, 56, 56)  33024       ['158[0][0]']
#
#  166 (Add)                      (None, 256, 56, 56)  0           ['330[0][0]',
#                                                                   '333[0][0]']
#
#  167 (Activation)               (None, 256, 56, 56)  0           ['166[0][0]']
#
#  336_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['167[0][0]']
#
#  336 (Conv2D)                   (None, 256, 56, 56)  590080      ['336_pad[0][0]']
#
#  170 (Activation)               (None, 256, 56, 56)  0           ['336[0][0]']
#
#  339_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['170[0][0]']
#
#  339 (Conv2D)                   (None, 256, 56, 56)  590080      ['339_pad[0][0]']
#
#  173 (Add)                      (None, 256, 56, 56)  0           ['339[0][0]',
#                                                                   '167[0][0]']
#
#  174 (Activation)               (None, 256, 56, 56)  0           ['173[0][0]']
#
#  342_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['174[0][0]']
#
#  342 (Conv2D)                   (None, 512, 28, 28)  1180160     ['342_pad[0][0]']
#
#  177 (Activation)               (None, 512, 28, 28)  0           ['342[0][0]']
#
#  345_pad (ZeroPadding2D)        (None, 512, 30, 30)  0           ['177[0][0]']
#
#  345 (Conv2D)                   (None, 512, 28, 28)  2359808     ['345_pad[0][0]']
#
#  348 (Conv2D)                   (None, 512, 28, 28)  131584      ['174[0][0]']
#
#  182 (Add)                      (None, 512, 28, 28)  0           ['345[0][0]',
#                                                                   '348[0][0]']
#
#  183 (Activation)               (None, 512, 28, 28)  0           ['182[0][0]']
#
#  351_pad (ZeroPadding2D)        (None, 512, 30, 30)  0           ['183[0][0]']
#
#  351 (Conv2D)                   (None, 512, 28, 28)  2359808     ['351_pad[0][0]']
#
#  186 (Activation)               (None, 512, 28, 28)  0           ['351[0][0]']
#
#  354_pad (ZeroPadding2D)        (None, 512, 30, 30)  0           ['186[0][0]']
#
#  354 (Conv2D)                   (None, 512, 28, 28)  2359808     ['354_pad[0][0]']
#
#  189 (Add)                      (None, 512, 28, 28)  0           ['354[0][0]',
#                                                                   '183[0][0]']
#
#  190 (Activation)               (None, 512, 28, 28)  0           ['189[0][0]']
#
#  191 (ZeroPadding2D)            (None, 512, 28, 28)  0           ['190[0][0]']
#
#  192_pad (ZeroPadding2D)        (None, 512, 28, 28)  0           ['191[0][0]']
#
#  192 (AveragePooling2D)         (None, 512, 1, 1)    0           ['192_pad[0][0]']
#
#  198 (Flatten)                  (None, 512)          0           ['192[0][0]']
#
#  199 (Dense)                    (None, 512)          262656      ['198[0][0]']
#
#  200 (Activation)               (None, 512)          0           ['199[0][0]']
#
#  output_0 (Dense)               (None, 128)          65664       ['200[0][0]']
#
#  202 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  203 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  218 (Lambda)                   (None, 1, 16)        0           ['202[0][0]']
#
#  227 (Lambda)                   (None, 1, 16)        0           ['203[0][0]']
#
#  204 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  220 (Subtract)                 (None, 16, 16)       0           ['218[0][0]']
#
#  229 (Subtract)                 (None, 16, 16)       0           ['227[0][0]']
#
#  237 (Lambda)                   (None, 1, 16)        0           ['204[0][0]']
#
#  205 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  221 (Multiply)                 (None, 16, 16)       0           ['220[0][0]',
#                                                                   '220[0][0]']
#
#  230 (Multiply)                 (None, 16, 16)       0           ['229[0][0]',
#                                                                   '229[0][0]']
#
#  239 (Subtract)                 (None, 16, 16)       0           ['237[0][0]']
#
#  247 (Lambda)                   (None, 1, 16)        0           ['205[0][0]']
#
#  206 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  222 (Lambda)                   (None, 16, 1)        0           ['221[0][0]']
#
#  224_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  231 (Lambda)                   (None, 16, 1)        0           ['230[0][0]']
#
#  233_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  240 (Multiply)                 (None, 16, 16)       0           ['239[0][0]',
#                                                                   '239[0][0]']
#
#  249 (Subtract)                 (None, 16, 16)       0           ['247[0][0]']
#
#  257 (Lambda)                   (None, 1, 16)        0           ['206[0][0]']
#
#  207 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  224 (Lambda)                   (None, 16, 1)        0           ['222[0][0]',
#                                                                   '224_const2[0][0]']
#
#  233 (Lambda)                   (None, 16, 1)        0           ['231[0][0]',
#                                                                   '233_const2[0][0]']
#
#  241 (Lambda)                   (None, 16, 1)        0           ['240[0][0]']
#
#  243_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  250 (Multiply)                 (None, 16, 16)       0           ['249[0][0]',
#                                                                   '249[0][0]']
#
#  259 (Subtract)                 (None, 16, 16)       0           ['257[0][0]']
#
#  267 (Lambda)                   (None, 1, 16)        0           ['207[0][0]']
#
#  208 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  225 (Lambda)                   (None, 16, 1)        0           ['224[0][0]']
#
#  234 (Lambda)                   (None, 16, 1)        0           ['233[0][0]']
#
#  243 (Lambda)                   (None, 16, 1)        0           ['241[0][0]',
#                                                                   '243_const2[0][0]']
#
#  251 (Lambda)                   (None, 16, 1)        0           ['250[0][0]']
#
#  253_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  260 (Multiply)                 (None, 16, 16)       0           ['259[0][0]',
#                                                                   '259[0][0]']
#
#  269 (Subtract)                 (None, 16, 16)       0           ['267[0][0]']
#
#  277 (Lambda)                   (None, 1, 16)        0           ['208[0][0]']
#
#  209 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  multiply (Multiply)            (16, 16, 16)         0           ['225[0][0]']
#
#  multiply_1 (Multiply)          (16, 16, 16)         0           ['234[0][0]']
#
#  244 (Lambda)                   (None, 16, 1)        0           ['243[0][0]']
#
#  253 (Lambda)                   (None, 16, 1)        0           ['251[0][0]',
#                                                                   '253_const2[0][0]']
#
#  261 (Lambda)                   (None, 16, 1)        0           ['260[0][0]']
#
#  263_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  270 (Multiply)                 (None, 16, 16)       0           ['269[0][0]',
#                                                                   '269[0][0]']
#
#  279 (Subtract)                 (None, 16, 16)       0           ['277[0][0]']
#
#  287 (Lambda)                   (None, 1, 16)        0           ['209[0][0]']
#
#  236 (Concatenate)              (16, 32, 16)         0           ['multiply[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  multiply_2 (Multiply)          (16, 16, 16)         0           ['244[0][0]']
#
#  254 (Lambda)                   (None, 16, 1)        0           ['253[0][0]']
#
#  263 (Lambda)                   (None, 16, 1)        0           ['261[0][0]',
#                                                                   '263_const2[0][0]']
#
#  271 (Lambda)                   (None, 16, 1)        0           ['270[0][0]']
#
#  273_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  280 (Multiply)                 (None, 16, 16)       0           ['279[0][0]',
#                                                                   '279[0][0]']
#
#  289 (Subtract)                 (None, 16, 16)       0           ['287[0][0]']
#
#  246 (Concatenate)              (16, 48, 16)         0           ['236[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  multiply_3 (Multiply)          (16, 16, 16)         0           ['254[0][0]']
#
#  264 (Lambda)                   (None, 16, 1)        0           ['263[0][0]']
#
#  273 (Lambda)                   (None, 16, 1)        0           ['271[0][0]',
#                                                                   '273_const2[0][0]']
#
#  281 (Lambda)                   (None, 16, 1)        0           ['280[0][0]']
#
#  283_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  290 (Multiply)                 (None, 16, 16)       0           ['289[0][0]',
#                                                                   '289[0][0]']
#
#  256 (Concatenate)              (16, 64, 16)         0           ['246[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (16, 16, 16)         0           ['264[0][0]']
#
#  274 (Lambda)                   (None, 16, 1)        0           ['273[0][0]']
#
#  283 (Lambda)                   (None, 16, 1)        0           ['281[0][0]',
#                                                                   '283_const2[0][0]']
#
#  291 (Lambda)                   (None, 16, 1)        0           ['290[0][0]']
#
#  293_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  266 (Concatenate)              (16, 80, 16)         0           ['256[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  multiply_5 (Multiply)          (16, 16, 16)         0           ['274[0][0]']
#
#  284 (Lambda)                   (None, 16, 1)        0           ['283[0][0]']
#
#  293 (Lambda)                   (None, 16, 1)        0           ['291[0][0]',
#                                                                   '293_const2[0][0]']
#
#  276 (Concatenate)              (16, 96, 16)         0           ['266[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  multiply_6 (Multiply)          (16, 16, 16)         0           ['284[0][0]']
#
#  294 (Lambda)                   (None, 16, 1)        0           ['293[0][0]']
#
#  286 (Concatenate)              (16, 112, 16)        0           ['276[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  multiply_7 (Multiply)          (16, 16, 16)         0           ['294[0][0]']
#
#  output_1 (Concatenate)         (16, 128, 16)        0           ['286[0][0]',
#                                                                   'multiply_7[0][0]']
#
# ==================================================================================================
# Total params: 11,492,352
# Trainable params: 11,492,352
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import the required library
import torch

# create an object x
x = torch.randint(100,(1,))
print(x)
print(int(x))


# check if the above created object is a tensor
print(torch.is_tensor(x))
# Out:
# tensor([23])
# 23
# True

# %%
k_model2 = pytorch_to_keras(my_model, input_var,[(3, 224, 224,)], verbose=True)
# Out:
# INFO:pytorch2keras:Converter is called.
# WARNING:pytorch2keras:Custom shapes isn't supported now.
# DEBUG:pytorch2keras:Input_names:
# DEBUG:pytorch2keras:['input_0']
# DEBUG:pytorch2keras:Output_names:
# DEBUG:pytorch2keras:['output_0', 'output_1']
# /content/drive/MyDrive/models/SPQ/utils.py:93: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   out = F.avg_pool2d(out, int(out.size()[3]))
# /content/drive/MyDrive/models/SPQ/utils.py:15: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   L_word = int(C.size()[1]/N_books)
# INFO:onnx2keras:Converter is called.
# DEBUG:onnx2keras:List input shapes:
# DEBUG:onnx2keras:[(3, 224, 224)]
# DEBUG:onnx2keras:List inputs:
# DEBUG:onnx2keras:Input 0 -> input_0.
# DEBUG:onnx2keras:List outputs:
# DEBUG:onnx2keras:Output 0 -> output_0.
# DEBUG:onnx2keras:Output 1 -> output_1.
# graph(%input_0 : Float(1, 3, 224, 224, strides=[150528, 50176, 224, 1], requires_grad=0, device=cpu),
#       %0.fc_out.weight : Float(512, 512, strides=[512, 1], requires_grad=1, device=cpu),
#       %0.fc_out.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %1.C : Float(16, 128, strides=[128, 1], requires_grad=1, device=cpu),
#       %1.fc.weight : Float(128, 512, strides=[512, 1], requires_grad=1, device=cpu),
#       %1.fc.bias : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %298 : Float(64, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %299 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %301 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %302 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %304 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %305 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %307 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %308 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %310 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %311 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %313 : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %314 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %316 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %317 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %319 : Float(128, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %320 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %322 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %323 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %325 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %326 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %328 : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %329 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %331 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %332 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %334 : Float(256, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %335 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %337 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %338 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %340 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %341 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %343 : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %344 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %346 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %347 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %349 : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %350 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %352 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %353 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %355 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %356 : Float(512, strides=[1], requires_grad=0, device=cpu)):
#   %297 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%input_0, %298, %299)
#   %128 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Relu(%297)
#   %300 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%128, %301, %302)
#   %131 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Relu(%300) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %303 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%131, %304, %305)
#   %134 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Add(%303, %128) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %135 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Relu(%134)
#   %306 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %307, %308)
#   %138 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Relu(%306) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %309 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%138, %310, %311)
#   %141 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Add(%309, %135) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %142 : Float(1, 64, 224, 224, strides=[3211264, 50176, 224, 1], requires_grad=1, device=cpu) = onnx::Relu(%141) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %312 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%142, %313, %314)
#   %145 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Relu(%312) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %315 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%145, %316, %317)
#   %318 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%142, %319, %320)
#   %150 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Add(%315, %318) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %151 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Relu(%150)
#   %321 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%151, %322, %323)
#   %154 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Relu(%321) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %324 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%154, %325, %326)
#   %157 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Add(%324, %151) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %158 : Float(1, 128, 112, 112, strides=[1605632, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Relu(%157) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %327 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%158, %328, %329)
#   %161 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%327) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %330 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%161, %331, %332)
#   %333 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%158, %334, %335)
#   %166 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Add(%330, %333) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %167 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%166)
#   %336 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%167, %337, %338)
#   %170 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%336) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %339 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%170, %340, %341)
#   %173 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Add(%339, %167) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %174 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%173) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %342 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%174, %343, %344)
#   %177 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%342) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %345 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%177, %346, %347)
#   %348 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%174, %349, %350)
#   %182 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Add(%345, %348) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %183 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%182)
#   %351 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%183, %352, %353)
#   %186 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%351) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %354 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%186, %355, %356)
#   %189 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Add(%354, %183) # /content/drive/MyDrive/models/SPQ/utils.py:60:0
#   %190 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%189) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %191 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], device=cpu) = onnx::Pad[mode="constant", pads=[0, 0, 0, 0, 0, 0, 0, 0], value=0.](%190)
#   %192 : Float(1, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu) = onnx::AveragePool[kernel_shape=[28, 28], pads=[0, 0, 0, 0], strides=[28, 28]](%191) # /content/drive/MyDrive/models/SPQ/utils.py:93:0
#   %193 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={1}]() # /content/drive/MyDrive/models/SPQ/utils.py:95:0
#   %194 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %195 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%193)
#   %196 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%194)
#   %197 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%195, %196)
#   %198 : Float(1, 512, strides=[512, 1], requires_grad=1, device=cpu) = onnx::Reshape(%192, %197) # /content/drive/MyDrive/models/SPQ/utils.py:95:0
#   %199 : Float(1, 512, strides=[512, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%198, %0.fc_out.weight, %0.fc_out.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1848:0
#   %200 : Float(1, 512, strides=[512, 1], requires_grad=1, device=cpu) = onnx::Relu(%199) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1299:0
#   %output_0 : Float(1, 128, strides=[128, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%200, %1.fc.weight, %1.fc.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1848:0
#   %202 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu), %203 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu), %204 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu), %205 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu), %206 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu), %207 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu), %208 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu), %209 : Float(1, 16, strides=[128, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[16, 16, 16, 16, 16, 16, 16, 16]](%output_0) # /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:510:0
#   %210 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu), %211 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu), %212 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu), %213 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu), %214 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu), %215 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu), %216 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu), %217 : Float(16, 16, strides=[128, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[16, 16, 16, 16, 16, 16, 16, 16]](%1.C) # /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:510:0
#   %218 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%202) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %219 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%210) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %220 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%218, %219) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %221 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%220, %220) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %222 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%221) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %223 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %224 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%222, %223)
#   %225 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%224) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %226 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%225, %210) # /content/drive/MyDrive/models/SPQ/utils.py:21:0
#   %227 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%203) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %228 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%211) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %229 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%227, %228) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %230 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%229, %229) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %231 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%230) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %232 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %233 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%231, %232)
#   %234 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%233) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %235 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%234, %211) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %236 : Float(1, 32, strides=[32, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%226, %235) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %237 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%204) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %238 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%212) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %239 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%237, %238) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %240 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%239, %239) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %241 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%240) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %242 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %243 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%241, %242)
#   %244 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%243) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %245 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%244, %212) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %246 : Float(1, 48, strides=[48, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%236, %245) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %247 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%205) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %248 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%213) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %249 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%247, %248) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %250 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%249, %249) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %251 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%250) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %252 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %253 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%251, %252)
#   %254 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%253) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %255 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%254, %213) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %256 : Float(1, 64, strides=[64, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%246, %255) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %257 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%206) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %258 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%214) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %259 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%257, %258) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %260 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%259, %259) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %261 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%260) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %262 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %263 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%261, %262)
#   %264 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%263) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %265 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%264, %214) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %266 : Float(1, 80, strides=[80, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%256, %265) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %267 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%207) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %268 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%215) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %269 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%267, %268) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %270 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%269, %269) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %271 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%270) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %272 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %273 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%271, %272)
#   %274 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%273) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %275 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%274, %215) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %276 : Float(1, 96, strides=[96, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%266, %275) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %277 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%208) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %278 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%216) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %279 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%277, %278) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %280 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%279, %279) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %281 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%280) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %282 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %283 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%281, %282)
#   %284 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%283) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %285 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%284, %216) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %286 : Float(1, 112, strides=[112, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%276, %285) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %287 : Float(1, 1, 16, strides=[128, 16, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%209) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %288 : Float(1, 16, 16, strides=[2048, 128, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[0]](%217) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %289 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Sub(%287, %288) # /content/drive/MyDrive/models/SPQ/utils.py:34:0
#   %290 : Float(1, 16, 16, strides=[256, 16, 1], requires_grad=1, device=cpu) = onnx::Mul(%289, %289) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %291 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[-1], keepdims=0](%290) # /content/drive/MyDrive/models/SPQ/utils.py:35:0
#   %292 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-5}]()
#   %293 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Mul(%291, %292)
#   %294 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::Softmax[axis=1](%293) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1680:0
#   %295 : Float(1, 16, strides=[16, 1], requires_grad=1, device=cpu) = onnx::MatMul(%294, %217) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   %output_1 : Float(1, 128, strides=[128, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%286, %295) # /content/drive/MyDrive/models/SPQ/utils.py:23:0
#   return (%output_0, %output_1)
# DEBUG:onnx2keras:Gathering weights to dictionary.
# DEBUG:onnx2keras:Found weight 0.fc_out.weight with shape (512, 512).
# DEBUG:onnx2keras:Found weight 0.fc_out.bias with shape (512,).
# DEBUG:onnx2keras:Found weight 1.C with shape (16, 128).
# DEBUG:onnx2keras:Found weight 1.fc.weight with shape (128, 512).
# DEBUG:onnx2keras:Found weight 1.fc.bias with shape (128,).
# DEBUG:onnx2keras:Found weight 298 with shape (64, 3, 3, 3).
# DEBUG:onnx2keras:Found weight 299 with shape (64,).
# DEBUG:onnx2keras:Found weight 301 with shape (64, 64, 3, 3).
# DEBUG:onnx2keras:Found weight 302 with shape (64,).
# DEBUG:onnx2keras:Found weight 304 with shape (64, 64, 3, 3).
# DEBUG:onnx2keras:Found weight 305 with shape (64,).
# DEBUG:onnx2keras:Found weight 307 with shape (64, 64, 3, 3).
# DEBUG:onnx2keras:Found weight 308 with shape (64,).
# DEBUG:onnx2keras:Found weight 310 with shape (64, 64, 3, 3).
# DEBUG:onnx2keras:Found weight 311 with shape (64,).
# DEBUG:onnx2keras:Found weight 313 with shape (128, 64, 3, 3).
# DEBUG:onnx2keras:Found weight 314 with shape (128,).
# DEBUG:onnx2keras:Found weight 316 with shape (128, 128, 3, 3).
# DEBUG:onnx2keras:Found weight 317 with shape (128,).
# DEBUG:onnx2keras:Found weight 319 with shape (128, 64, 1, 1).
# DEBUG:onnx2keras:Found weight 320 with shape (128,).
# DEBUG:onnx2keras:Found weight 322 with shape (128, 128, 3, 3).
# DEBUG:onnx2keras:Found weight 323 with shape (128,).
# DEBUG:onnx2keras:Found weight 325 with shape (128, 128, 3, 3).
# DEBUG:onnx2keras:Found weight 326 with shape (128,).
# DEBUG:onnx2keras:Found weight 328 with shape (256, 128, 3, 3).
# DEBUG:onnx2keras:Found weight 329 with shape (256,).
# DEBUG:onnx2keras:Found weight 331 with shape (256, 256, 3, 3).
# DEBUG:onnx2keras:Found weight 332 with shape (256,).
# DEBUG:onnx2keras:Found weight 334 with shape (256, 128, 1, 1).
# DEBUG:onnx2keras:Found weight 335 with shape (256,).
# DEBUG:onnx2keras:Found weight 337 with shape (256, 256, 3, 3).
# DEBUG:onnx2keras:Found weight 338 with shape (256,).
# DEBUG:onnx2keras:Found weight 340 with shape (256, 256, 3, 3).
# DEBUG:onnx2keras:Found weight 341 with shape (256,).
# DEBUG:onnx2keras:Found weight 343 with shape (512, 256, 3, 3).
# DEBUG:onnx2keras:Found weight 344 with shape (512,).
# DEBUG:onnx2keras:Found weight 346 with shape (512, 512, 3, 3).
# DEBUG:onnx2keras:Found weight 347 with shape (512,).
# DEBUG:onnx2keras:Found weight 349 with shape (512, 256, 1, 1).
# DEBUG:onnx2keras:Found weight 350 with shape (512,).
# DEBUG:onnx2keras:Found weight 352 with shape (512, 512, 3, 3).
# DEBUG:onnx2keras:Found weight 353 with shape (512,).
# DEBUG:onnx2keras:Found weight 355 with shape (512, 512, 3, 3).
# DEBUG:onnx2keras:Found weight 356 with shape (512,).
# DEBUG:onnx2keras:Found input input_0 with shape (3, 224, 224)
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 297
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name input_0).
# DEBUG:onnx2keras:Check input 1 (name 298).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 299).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='297/BiasAdd:0', description="created by layer '297'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 128
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 297).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='128/Relu:0', description="created by layer '128'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 300
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 128).
# DEBUG:onnx2keras:Check input 1 (name 301).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 302).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='300/BiasAdd:0', description="created by layer '300'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 131
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 300).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='131/Relu:0', description="created by layer '131'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 303
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 131).
# DEBUG:onnx2keras:Check input 1 (name 304).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 305).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='303/BiasAdd:0', description="created by layer '303'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Add
# DEBUG:onnx2keras:node_name: 134
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 303).
# DEBUG:onnx2keras:Check input 1 (name 128).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:add:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='134/add:0', description="created by layer '134'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 135
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 134).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='135/Relu:0', description="created by layer '135'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 306
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 135).
# DEBUG:onnx2keras:Check input 1 (name 307).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 308).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='306/BiasAdd:0', description="created by layer '306'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 138
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 306).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='138/Relu:0', description="created by layer '138'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 309
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 138).
# DEBUG:onnx2keras:Check input 1 (name 310).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 311).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='309/BiasAdd:0', description="created by layer '309'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Add
# DEBUG:onnx2keras:node_name: 141
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 309).
# DEBUG:onnx2keras:Check input 1 (name 135).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:add:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='141/add:0', description="created by layer '141'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 142
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 141).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 64, 224, 224), dtype=tf.float32, name=None), name='142/Relu:0', description="created by layer '142'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 312
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [2, 2], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 142).
# DEBUG:onnx2keras:Check input 1 (name 313).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 314).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='312/BiasAdd:0', description="created by layer '312'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 145
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 312).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='145/Relu:0', description="created by layer '145'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 315
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 145).
# DEBUG:onnx2keras:Check input 1 (name 316).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 317).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='315/BiasAdd:0', description="created by layer '315'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 318
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [2, 2], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 142).
# DEBUG:onnx2keras:Check input 1 (name 319).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 320).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='318/BiasAdd:0', description="created by layer '318'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Add
# DEBUG:onnx2keras:node_name: 150
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 315).
# DEBUG:onnx2keras:Check input 1 (name 318).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:add:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='150/add:0', description="created by layer '150'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 151
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 150).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='151/Relu:0', description="created by layer '151'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 321
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 151).
# DEBUG:onnx2keras:Check input 1 (name 322).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 323).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='321/BiasAdd:0', description="created by layer '321'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Relu
# DEBUG:onnx2keras:node_name: 154
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 321).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='154/Relu:0', description="created by layer '154'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 324
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 154).
# DEBUG:onnx2keras:Check input 1 (name 325).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 326).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 128, 112, 112), dtype=tf.float32, name=None), name='324/BiasAdd:0', description="created by layer '324'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Add
# DEBUG:onnx2keras:node_name: 157
# ...
#    -4.47877566e-04 -9.32013849e-04  6.04816293e-03 -2.51955935e-04
#    -2.99967546e-03  6.70837983e-03  2.47428670e-05 -6.70006848e-04]
#   [ 3.50346636e-05 -1.54532881e-05  4.02708138e-05  9.87036910e-05
#     5.83157269e-03  2.80390121e-03 -4.76307498e-04 -1.72868383e-03
#     6.61479309e-03  2.70469859e-03  2.83468259e-03 -3.41664348e-03
#     8.30810401e-04 -3.14393925e-04  2.01350758e-05  1.20565817e-02]]], shape=(1, 16, 16), dtype=float32)
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Sub
# DEBUG:onnx2keras:node_name: 279
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 277).
# DEBUG:onnx2keras:Check input 1 (name 278).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:sub:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16), dtype=tf.float32, name=None), name='279/sub:0', description="created by layer '279'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Mul
# DEBUG:onnx2keras:node_name: 280
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 279).
# DEBUG:onnx2keras:Check input 1 (name 279).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:mul:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16), dtype=tf.float32, name=None), name='280/mul:0', description="created by layer '280'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: ReduceSum
# DEBUG:onnx2keras:node_name: 281
# DEBUG:onnx2keras:node_params: {'axes': [-1], 'keepdims': 0, 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 280).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 1), dtype=tf.float32, name=None), name='281/Sum:0', description="created by layer '281'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Constant
# DEBUG:onnx2keras:node_name: 282
# DEBUG:onnx2keras:node_params: {'value': array(-5., dtype=float32), 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> -5.0
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Mul
# DEBUG:onnx2keras:node_name: 283
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 281).
# DEBUG:onnx2keras:Check input 1 (name 282).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:mul:Convert inputs to Keras/TF layers if needed.
# WARNING:onnx2keras:mul:Failed to use keras.layers.Multiply. Fallback to TF lambda.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 1), dtype=tf.float32, name=None), name='283/Mul:0', description="created by layer '283'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Softmax
# DEBUG:onnx2keras:node_name: 284
# DEBUG:onnx2keras:node_params: {'axis': 1, 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 283).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 1), dtype=tf.float32, name=None), name='284/transpose_1:0', description="created by layer '284'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: MatMul
# DEBUG:onnx2keras:node_name: 285
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 284).
# DEBUG:onnx2keras:Check input 1 (name 216).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:gemm:Convert GEMM without bias.
# DEBUG:onnx2keras:gemm:Input units 16, output units 16.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(16, 16, 16), dtype=tf.float32, name=None), name='multiply_14/mul:0', description="created by layer 'multiply_14'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Concat
# DEBUG:onnx2keras:node_name: 286
# DEBUG:onnx2keras:node_params: {'axis': 1, 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 276).
# DEBUG:onnx2keras:Check input 1 (name 285).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:concat:Concat Keras layers.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(16, 112, 16), dtype=tf.float32, name=None), name='286/concat:0', description="created by layer '286'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Unsqueeze
# DEBUG:onnx2keras:node_name: 287
# DEBUG:onnx2keras:node_params: {'axes': [1], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 209).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 1, 16), dtype=tf.float32, name=None), name='287/ExpandDims:0', description="created by layer '287'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Unsqueeze
# DEBUG:onnx2keras:node_name: 288
# DEBUG:onnx2keras:node_params: {'axes': [0], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 217).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> tf.Tensor(
# [[[-3.93109622e-05 -1.54029233e-02 -4.01589461e-02 -3.97601351e-02
#     2.45913421e-03 -5.61789908e-02 -1.51180327e-02 -1.77904498e-02
#    -1.26130171e-05 -4.17993031e-02  1.20514855e-02  4.76513281e-02
#     3.30893695e-03  5.83194010e-02  7.16546774e-02  8.46741386e-05]
#   [-8.17135733e-05 -5.43516092e-02 -4.12367024e-02 -5.30103967e-03
#    -7.21898768e-03 -5.62613122e-02 -1.36522092e-02 -2.04429328e-02
#     1.74606874e-04  3.05863116e-02 -2.79890541e-02  9.44299027e-02
#     1.05421953e-02 -9.71376449e-02  3.36011015e-02 -6.34669850e-05]
#   [-1.25319159e-04  5.40641136e-02  4.78316881e-02  7.02447966e-02
#     7.23861158e-03 -1.33727808e-02 -5.83889112e-02 -6.89930394e-02
#     3.95777606e-05 -7.02739600e-03  8.21343884e-02  2.94554196e-02
#    -2.20621401e-03 -2.31307335e-02  2.70443526e-03 -1.02675585e-04]
#   [ 4.52655659e-05  4.09524073e-04  5.61252981e-03  2.01482745e-03
#     4.13757138e-04  8.58042669e-03  1.45911388e-02 -2.43201642e-03
#    -3.13519631e-05  5.49131306e-03  5.39223081e-04  6.95574097e-03
#    -2.67173885e-03  1.85988657e-02  3.57729034e-03 -4.48399296e-05]
#   [ 7.17013754e-05  8.34276341e-03 -1.11471042e-02  1.68552343e-03
#    -1.19719130e-03  8.28144886e-03 -2.16657016e-02  1.23904115e-02
#    -5.07630975e-05 -2.09326167e-02 -2.95313587e-03 -1.97112467e-02
#     1.71399710e-03 -9.09256656e-03 -1.67062674e-02  2.16993692e-04]
#   [-1.50711072e-04 -5.46183530e-03 -1.07097533e-02 -5.22556901e-02
#    -1.81359274e-03  5.07040173e-02  5.42005301e-02  6.79337829e-02
#     7.46308142e-05 -1.52366702e-02 -4.55757789e-02 -8.70856568e-02
#    -6.42921822e-03  8.49086642e-02 -2.61804815e-02 -1.39043259e-04]
#   [-2.97887509e-05 -9.53657366e-03  1.81032866e-02  3.25944610e-02
#    -6.08119415e-03  3.19385156e-02  2.20280662e-02  1.24881864e-02
#    -2.14190313e-05  4.85693514e-02 -3.20154466e-02 -9.48738959e-03
#     6.46013796e-05 -9.72970873e-02 -5.91023825e-02 -3.63375948e-05]
#   [-9.61530241e-05 -8.21203664e-02 -4.91420217e-02 -6.72325268e-02
#    -1.19773149e-02 -1.41524840e-02  1.65687278e-02  6.37421682e-02
#     9.46812797e-05  5.15843295e-02 -7.74643943e-02 -2.49842461e-03
#     6.69695763e-03 -1.77461319e-02  3.01583409e-02 -4.66693600e-05]
#   [ 2.58187647e-04  5.27587272e-02  6.54239357e-02  2.74894554e-02
#     8.43559485e-03  3.87270525e-02 -4.23398092e-02  4.81874589e-03
#    -2.90181400e-04  7.60031072e-03  6.18374683e-02 -8.77478644e-02
#    -1.04465913e-02  7.67763928e-02 -5.90505358e-03  9.75242874e-05]
#   [ 1.17989352e-04  3.55994217e-02 -1.72493048e-02  4.18140627e-02
#     3.42237274e-03 -2.16535442e-02  3.26641351e-02 -7.22027197e-02
#     7.43527244e-06 -6.88318461e-02  1.62971057e-02  9.20810997e-02
#     3.78476200e-03 -5.68166301e-02 -3.08594853e-02  9.95547816e-05]
#   [-2.26949560e-04 -1.66405421e-02 -6.57562837e-02 -3.85959223e-02
#    -4.49679047e-03  6.00191252e-03  1.01252742e-01  1.05024967e-02
#     1.67417384e-04 -6.63477480e-02 -7.30507076e-02  4.17326093e-02
#     3.87574174e-03 -1.18595958e-02 -4.08820547e-02 -1.30797300e-04]
#   [-6.20102946e-05  7.60288239e-02  1.42539972e-02  2.91507021e-02
#     8.51900503e-03  3.87292430e-02  5.60358688e-02 -3.27427834e-02
#     3.37652891e-05 -9.38189477e-02  2.58978009e-02 -1.43076936e-02
#    -6.54838700e-03  4.95861173e-02 -6.30566105e-02 -8.36593972e-05]
#   [ 4.15514747e-04 -2.23508682e-02  3.57303359e-02  2.53663287e-02
#    -2.03661664e-04 -3.63933109e-02 -9.96605754e-02 -1.16326008e-02
#    -2.34328239e-04  8.47016275e-02  4.50520590e-02  7.25102937e-03
#     2.80525745e-03 -4.01092656e-02  5.97862415e-02  2.36419815e-04]
#   [ 6.62125531e-05  4.33103181e-03  7.49347406e-03  1.22445147e-03
#     7.32882298e-04  3.71708837e-03  9.33939964e-03  1.12277572e-03
#    -4.77313843e-05 -3.96223180e-03  3.44517478e-03 -9.13628656e-03
#    -1.56169210e-03  1.26003418e-02 -2.98381783e-03  3.81937025e-05]
#   [ 6.25360335e-05  7.53600243e-03  6.11460861e-03 -6.23995112e-03
#     1.61566818e-03  2.45811185e-03  9.78312641e-03 -3.63251148e-03
#    -4.69224578e-05 -3.15679819e-04  4.17979434e-03 -7.68212508e-03
#     2.12451167e-04  1.33819832e-02 -2.83534522e-03  4.25281796e-05]
#   [ 5.55590304e-05 -4.15212475e-02  2.36050729e-02 -3.02372966e-02
#    -2.52619735e-03  6.08666101e-03 -5.89393638e-02  5.98904416e-02
#    -8.60957080e-05  8.83130357e-02 -3.38099920e-03 -7.40311146e-02
#    -2.25534383e-03  3.29674147e-02  4.69880067e-02 -1.20114091e-05]]], shape=(1, 16, 16), dtype=float32)
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Sub
# DEBUG:onnx2keras:node_name: 289
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 287).
# DEBUG:onnx2keras:Check input 1 (name 288).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:sub:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16), dtype=tf.float32, name=None), name='289/sub:0', description="created by layer '289'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Mul
# DEBUG:onnx2keras:node_name: 290
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 289).
# DEBUG:onnx2keras:Check input 1 (name 289).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:mul:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16), dtype=tf.float32, name=None), name='290/mul:0', description="created by layer '290'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: ReduceSum
# DEBUG:onnx2keras:node_name: 291
# DEBUG:onnx2keras:node_params: {'axes': [-1], 'keepdims': 0, 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 290).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 1), dtype=tf.float32, name=None), name='291/Sum:0', description="created by layer '291'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Constant
# DEBUG:onnx2keras:node_name: 292
# DEBUG:onnx2keras:node_params: {'value': array(-5., dtype=float32), 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> -5.0
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Mul
# DEBUG:onnx2keras:node_name: 293
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 291).
# DEBUG:onnx2keras:Check input 1 (name 292).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:mul:Convert inputs to Keras/TF layers if needed.
# WARNING:onnx2keras:mul:Failed to use keras.layers.Multiply. Fallback to TF lambda.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 1), dtype=tf.float32, name=None), name='293/Mul:0', description="created by layer '293'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Softmax
# DEBUG:onnx2keras:node_name: 294
# DEBUG:onnx2keras:node_params: {'axis': 1, 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 293).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 1), dtype=tf.float32, name=None), name='294/transpose_1:0', description="created by layer '294'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: MatMul
# DEBUG:onnx2keras:node_name: 295
# DEBUG:onnx2keras:node_params: {'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 294).
# DEBUG:onnx2keras:Check input 1 (name 217).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:gemm:Convert GEMM without bias.
# DEBUG:onnx2keras:gemm:Input units 16, output units 16.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(16, 16, 16), dtype=tf.float32, name=None), name='multiply_15/mul:0', description="created by layer 'multiply_15'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Concat
# DEBUG:onnx2keras:node_name: output_1
# DEBUG:onnx2keras:node_params: {'axis': 1, 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 286).
# DEBUG:onnx2keras:Check input 1 (name 295).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:concat:Concat Keras layers.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(16, 128, 16), dtype=tf.float32, name=None), name='output_1/concat:0', description="created by layer 'output_1'")

# %%
k_model2.summary ()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_0 (InputLayer)           [(None, 3, 224, 224  0           []
#                                 )]
#
#  297_pad (ZeroPadding2D)        (None, 3, 226, 226)  0           ['input_0[0][0]']
#
#  297 (Conv2D)                   (None, 64, 224, 224  1792        ['297_pad[0][0]']
#                                 )
#
#  128 (Activation)               (None, 64, 224, 224  0           ['297[0][0]']
#                                 )
#
#  300_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['128[0][0]']
#                                 )
#
#  300 (Conv2D)                   (None, 64, 224, 224  36928       ['300_pad[0][0]']
#                                 )
#
#  131 (Activation)               (None, 64, 224, 224  0           ['300[0][0]']
#                                 )
#
#  303_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['131[0][0]']
#                                 )
#
#  303 (Conv2D)                   (None, 64, 224, 224  36928       ['303_pad[0][0]']
#                                 )
#
#  134 (Add)                      (None, 64, 224, 224  0           ['303[0][0]',
#                                 )                                 '128[0][0]']
#
#  135 (Activation)               (None, 64, 224, 224  0           ['134[0][0]']
#                                 )
#
#  306_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['135[0][0]']
#                                 )
#
#  306 (Conv2D)                   (None, 64, 224, 224  36928       ['306_pad[0][0]']
#                                 )
#
#  138 (Activation)               (None, 64, 224, 224  0           ['306[0][0]']
#                                 )
#
#  309_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['138[0][0]']
#                                 )
#
#  309 (Conv2D)                   (None, 64, 224, 224  36928       ['309_pad[0][0]']
#                                 )
#
#  141 (Add)                      (None, 64, 224, 224  0           ['309[0][0]',
#                                 )                                 '135[0][0]']
#
#  142 (Activation)               (None, 64, 224, 224  0           ['141[0][0]']
#                                 )
#
#  312_pad (ZeroPadding2D)        (None, 64, 226, 226  0           ['142[0][0]']
#                                 )
#
#  312 (Conv2D)                   (None, 128, 112, 11  73856       ['312_pad[0][0]']
#                                 2)
#
#  145 (Activation)               (None, 128, 112, 11  0           ['312[0][0]']
#                                 2)
#
#  315_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['145[0][0]']
#                                 4)
#
#  315 (Conv2D)                   (None, 128, 112, 11  147584      ['315_pad[0][0]']
#                                 2)
#
#  318 (Conv2D)                   (None, 128, 112, 11  8320        ['142[0][0]']
#                                 2)
#
#  150 (Add)                      (None, 128, 112, 11  0           ['315[0][0]',
#                                 2)                                '318[0][0]']
#
#  151 (Activation)               (None, 128, 112, 11  0           ['150[0][0]']
#                                 2)
#
#  321_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['151[0][0]']
#                                 4)
#
#  321 (Conv2D)                   (None, 128, 112, 11  147584      ['321_pad[0][0]']
#                                 2)
#
#  154 (Activation)               (None, 128, 112, 11  0           ['321[0][0]']
#                                 2)
#
#  324_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['154[0][0]']
#                                 4)
#
#  324 (Conv2D)                   (None, 128, 112, 11  147584      ['324_pad[0][0]']
#                                 2)
#
#  157 (Add)                      (None, 128, 112, 11  0           ['324[0][0]',
#                                 2)                                '151[0][0]']
#
#  158 (Activation)               (None, 128, 112, 11  0           ['157[0][0]']
#                                 2)
#
#  327_pad (ZeroPadding2D)        (None, 128, 114, 11  0           ['158[0][0]']
#                                 4)
#
#  327 (Conv2D)                   (None, 256, 56, 56)  295168      ['327_pad[0][0]']
#
#  161 (Activation)               (None, 256, 56, 56)  0           ['327[0][0]']
#
#  330_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['161[0][0]']
#
#  330 (Conv2D)                   (None, 256, 56, 56)  590080      ['330_pad[0][0]']
#
#  333 (Conv2D)                   (None, 256, 56, 56)  33024       ['158[0][0]']
#
#  166 (Add)                      (None, 256, 56, 56)  0           ['330[0][0]',
#                                                                   '333[0][0]']
#
#  167 (Activation)               (None, 256, 56, 56)  0           ['166[0][0]']
#
#  336_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['167[0][0]']
#
#  336 (Conv2D)                   (None, 256, 56, 56)  590080      ['336_pad[0][0]']
#
#  170 (Activation)               (None, 256, 56, 56)  0           ['336[0][0]']
#
#  339_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['170[0][0]']
#
#  339 (Conv2D)                   (None, 256, 56, 56)  590080      ['339_pad[0][0]']
#
#  173 (Add)                      (None, 256, 56, 56)  0           ['339[0][0]',
#                                                                   '167[0][0]']
#
#  174 (Activation)               (None, 256, 56, 56)  0           ['173[0][0]']
#
#  342_pad (ZeroPadding2D)        (None, 256, 58, 58)  0           ['174[0][0]']
#
#  342 (Conv2D)                   (None, 512, 28, 28)  1180160     ['342_pad[0][0]']
#
#  177 (Activation)               (None, 512, 28, 28)  0           ['342[0][0]']
#
#  345_pad (ZeroPadding2D)        (None, 512, 30, 30)  0           ['177[0][0]']
#
#  345 (Conv2D)                   (None, 512, 28, 28)  2359808     ['345_pad[0][0]']
#
#  348 (Conv2D)                   (None, 512, 28, 28)  131584      ['174[0][0]']
#
#  182 (Add)                      (None, 512, 28, 28)  0           ['345[0][0]',
#                                                                   '348[0][0]']
#
#  183 (Activation)               (None, 512, 28, 28)  0           ['182[0][0]']
#
#  351_pad (ZeroPadding2D)        (None, 512, 30, 30)  0           ['183[0][0]']
#
#  351 (Conv2D)                   (None, 512, 28, 28)  2359808     ['351_pad[0][0]']
#
#  186 (Activation)               (None, 512, 28, 28)  0           ['351[0][0]']
#
#  354_pad (ZeroPadding2D)        (None, 512, 30, 30)  0           ['186[0][0]']
#
#  354 (Conv2D)                   (None, 512, 28, 28)  2359808     ['354_pad[0][0]']
#
#  189 (Add)                      (None, 512, 28, 28)  0           ['354[0][0]',
#                                                                   '183[0][0]']
#
#  190 (Activation)               (None, 512, 28, 28)  0           ['189[0][0]']
#
#  191 (ZeroPadding2D)            (None, 512, 28, 28)  0           ['190[0][0]']
#
#  192_pad (ZeroPadding2D)        (None, 512, 28, 28)  0           ['191[0][0]']
#
#  192 (AveragePooling2D)         (None, 512, 1, 1)    0           ['192_pad[0][0]']
#
#  198 (Flatten)                  (None, 512)          0           ['192[0][0]']
#
#  199 (Dense)                    (None, 512)          262656      ['198[0][0]']
#
#  200 (Activation)               (None, 512)          0           ['199[0][0]']
#
#  output_0 (Dense)               (None, 128)          65664       ['200[0][0]']
#
#  202 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  203 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  218 (Lambda)                   (None, 1, 16)        0           ['202[0][0]']
#
#  227 (Lambda)                   (None, 1, 16)        0           ['203[0][0]']
#
#  204 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  220 (Subtract)                 (None, 16, 16)       0           ['218[0][0]']
#
#  229 (Subtract)                 (None, 16, 16)       0           ['227[0][0]']
#
#  237 (Lambda)                   (None, 1, 16)        0           ['204[0][0]']
#
#  205 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  221 (Multiply)                 (None, 16, 16)       0           ['220[0][0]',
#                                                                   '220[0][0]']
#
#  230 (Multiply)                 (None, 16, 16)       0           ['229[0][0]',
#                                                                   '229[0][0]']
#
#  239 (Subtract)                 (None, 16, 16)       0           ['237[0][0]']
#
#  247 (Lambda)                   (None, 1, 16)        0           ['205[0][0]']
#
#  206 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  222 (Lambda)                   (None, 16, 1)        0           ['221[0][0]']
#
#  224_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  231 (Lambda)                   (None, 16, 1)        0           ['230[0][0]']
#
#  233_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  240 (Multiply)                 (None, 16, 16)       0           ['239[0][0]',
#                                                                   '239[0][0]']
#
#  249 (Subtract)                 (None, 16, 16)       0           ['247[0][0]']
#
#  257 (Lambda)                   (None, 1, 16)        0           ['206[0][0]']
#
#  207 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  224 (Lambda)                   (None, 16, 1)        0           ['222[0][0]',
#                                                                   '224_const2[0][0]']
#
#  233 (Lambda)                   (None, 16, 1)        0           ['231[0][0]',
#                                                                   '233_const2[0][0]']
#
#  241 (Lambda)                   (None, 16, 1)        0           ['240[0][0]']
#
#  243_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  250 (Multiply)                 (None, 16, 16)       0           ['249[0][0]',
#                                                                   '249[0][0]']
#
#  259 (Subtract)                 (None, 16, 16)       0           ['257[0][0]']
#
#  267 (Lambda)                   (None, 1, 16)        0           ['207[0][0]']
#
#  208 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  225 (Lambda)                   (None, 16, 1)        0           ['224[0][0]']
#
#  234 (Lambda)                   (None, 16, 1)        0           ['233[0][0]']
#
#  243 (Lambda)                   (None, 16, 1)        0           ['241[0][0]',
#                                                                   '243_const2[0][0]']
#
#  251 (Lambda)                   (None, 16, 1)        0           ['250[0][0]']
#
#  253_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  260 (Multiply)                 (None, 16, 16)       0           ['259[0][0]',
#                                                                   '259[0][0]']
#
#  269 (Subtract)                 (None, 16, 16)       0           ['267[0][0]']
#
#  277 (Lambda)                   (None, 1, 16)        0           ['208[0][0]']
#
#  209 (Lambda)                   (None, 16)           0           ['output_0[0][0]']
#
#  multiply_8 (Multiply)          (16, 16, 16)         0           ['225[0][0]']
#
#  multiply_9 (Multiply)          (16, 16, 16)         0           ['234[0][0]']
#
#  244 (Lambda)                   (None, 16, 1)        0           ['243[0][0]']
#
#  253 (Lambda)                   (None, 16, 1)        0           ['251[0][0]',
#                                                                   '253_const2[0][0]']
#
#  261 (Lambda)                   (None, 16, 1)        0           ['260[0][0]']
#
#  263_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  270 (Multiply)                 (None, 16, 16)       0           ['269[0][0]',
#                                                                   '269[0][0]']
#
#  279 (Subtract)                 (None, 16, 16)       0           ['277[0][0]']
#
#  287 (Lambda)                   (None, 1, 16)        0           ['209[0][0]']
#
#  236 (Concatenate)              (16, 32, 16)         0           ['multiply_8[0][0]',
#                                                                   'multiply_9[0][0]']
#
#  multiply_10 (Multiply)         (16, 16, 16)         0           ['244[0][0]']
#
#  254 (Lambda)                   (None, 16, 1)        0           ['253[0][0]']
#
#  263 (Lambda)                   (None, 16, 1)        0           ['261[0][0]',
#                                                                   '263_const2[0][0]']
#
#  271 (Lambda)                   (None, 16, 1)        0           ['270[0][0]']
#
#  273_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  280 (Multiply)                 (None, 16, 16)       0           ['279[0][0]',
#                                                                   '279[0][0]']
#
#  289 (Subtract)                 (None, 16, 16)       0           ['287[0][0]']
#
#  246 (Concatenate)              (16, 48, 16)         0           ['236[0][0]',
#                                                                   'multiply_10[0][0]']
#
#  multiply_11 (Multiply)         (16, 16, 16)         0           ['254[0][0]']
#
#  264 (Lambda)                   (None, 16, 1)        0           ['263[0][0]']
#
#  273 (Lambda)                   (None, 16, 1)        0           ['271[0][0]',
#                                                                   '273_const2[0][0]']
#
#  281 (Lambda)                   (None, 16, 1)        0           ['280[0][0]']
#
#  283_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  290 (Multiply)                 (None, 16, 16)       0           ['289[0][0]',
#                                                                   '289[0][0]']
#
#  256 (Concatenate)              (16, 64, 16)         0           ['246[0][0]',
#                                                                   'multiply_11[0][0]']
#
#  multiply_12 (Multiply)         (16, 16, 16)         0           ['264[0][0]']
#
#  274 (Lambda)                   (None, 16, 1)        0           ['273[0][0]']
#
#  283 (Lambda)                   (None, 16, 1)        0           ['281[0][0]',
#                                                                   '283_const2[0][0]']
#
#  291 (Lambda)                   (None, 16, 1)        0           ['290[0][0]']
#
#  293_const2 (Lambda)            ()                   0           ['input_0[0][0]']
#
#  266 (Concatenate)              (16, 80, 16)         0           ['256[0][0]',
#                                                                   'multiply_12[0][0]']
#
#  multiply_13 (Multiply)         (16, 16, 16)         0           ['274[0][0]']
#
#  284 (Lambda)                   (None, 16, 1)        0           ['283[0][0]']
#
#  293 (Lambda)                   (None, 16, 1)        0           ['291[0][0]',
#                                                                   '293_const2[0][0]']
#
#  276 (Concatenate)              (16, 96, 16)         0           ['266[0][0]',
#                                                                   'multiply_13[0][0]']
#
#  multiply_14 (Multiply)         (16, 16, 16)         0           ['284[0][0]']
#
#  294 (Lambda)                   (None, 16, 1)        0           ['293[0][0]']
#
#  286 (Concatenate)              (16, 112, 16)        0           ['276[0][0]',
#                                                                   'multiply_14[0][0]']
#
#  multiply_15 (Multiply)         (16, 16, 16)         0           ['294[0][0]']
#
#  output_1 (Concatenate)         (16, 128, 16)        0           ['286[0][0]',
#                                                                   'multiply_15[0][0]']
#
# ==================================================================================================
# Total params: 11,492,352
# Trainable params: 11,492,352
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.models.save_model(k_model2,'my_p2k_model.ckpt')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: my_p2k_model.ckpt/assets
# INFO:tensorflow:Assets written to: my_p2k_model.ckpt/assets
